# %%
# %matplotlib inline

# Filter warnings
import warnings
warnings.filterwarnings("ignore")

# Data manipulation
import pandas as pd
import numpy as np

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import *
import plotnine

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv('powerconsumption.csv')
print("Data size:", df.shape) # print data size
df.head(-5)
# Out:
# Data size: (52416, 9)
#                Datetime  Temperature  Humidity  WindSpeed  \
# 0         1/1/2017 0:00        6.559      73.8      0.083
# 1         1/1/2017 0:10        6.414      74.5      0.083
# 2         1/1/2017 0:20        6.313      74.5      0.080
# 3         1/1/2017 0:30        6.121      75.0      0.083
# 4         1/1/2017 0:40        5.921      75.7      0.081
# ...                 ...          ...       ...        ...
# 52406  12/30/2017 22:20        7.650      70.1      0.081
# 52407  12/30/2017 22:30        7.480      71.0      0.085
# 52408  12/30/2017 22:40        7.390      71.2      0.079
# 52409  12/30/2017 22:50        7.340      71.0      0.084
# 52410  12/30/2017 23:00        7.070      72.5      0.080
#
#        GeneralDiffuseFlows  DiffuseFlows  PowerConsumption_Zone1  \
# 0                    0.051         0.119             34055.69620
# 1                    0.070         0.085             29814.68354
# 2                    0.062         0.100             29128.10127
# 3                    0.091         0.096             28228.86076
# 4                    0.048         0.085             27335.69620
# ...                    ...           ...                     ...
# 52406                0.062         0.122             34323.95437
# 52407                0.062         0.104             33776.42586
# 52408                0.066         0.100             33387.07224
# 52409                0.037         0.119             32815.20913
# 52410                0.059         0.093             32158.17490
#
#        PowerConsumption_Zone2  PowerConsumption_Zone3
# 0                 16128.87538             20240.96386
# 1                 19375.07599             20131.08434
# 2                 19006.68693             19668.43373
# 3                 18361.09422             18899.27711
# 4                 17872.34043             18442.40964
# ...                       ...                     ...
# 52406             28676.28107             15684.99400
# 52407             28230.74563             15546.69868
# 52408             27814.66708             15396.87875
# 52409             27564.28352             15172.14886
# 52410             27273.39675             14987.75510
#
# [52411 rows x 9 columns]

# %% [markdown]
# # Data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52416 entries, 0 to 52415
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Datetime                52416 non-null  object
#  1   Temperature             52416 non-null  float64
#  2   Humidity                52416 non-null  float64
#  3   WindSpeed               52416 non-null  float64
#  4   GeneralDiffuseFlows     52416 non-null  float64
#  5   DiffuseFlows            52416 non-null  float64
#  6   PowerConsumption_Zone1  52416 non-null  float64
#  7   PowerConsumption_Zone2  52416 non-null  float64
#  8   PowerConsumption_Zone3  52416 non-null  float64
# dtypes: float64(8), object(1)
# memory usage: 3.6+ MB

# %%
# converting Datetime column to datetime type
df['Datetime'] = pd.to_datetime(df['Datetime'])
df.rename(columns = {'Datetime':'Date'}, inplace = True)
dfu=df

# %%
df = df.set_index('Date')

# %% [markdown]
# # Check missing values

# %%
df.isnull().sum()/len(df)*100
# Out:
# Temperature               0.0
# Humidity                  0.0
# WindSpeed                 0.0
# GeneralDiffuseFlows       0.0
# DiffuseFlows              0.0
# PowerConsumption_Zone1    0.0
# PowerConsumption_Zone2    0.0
# PowerConsumption_Zone3    0.0
# dtype: float64

# %% [markdown]
# # Unique Values

# %%
dfs=df.nunique().reset_index()
dfs.columns = ['feature','nunique']
dfs=dfs.drop(dfs.index[0])
dfs
# Out:
#                   feature  nunique
# 1             Temperature     3437
# 2                Humidity     4443
# 3               WindSpeed      548
# 4     GeneralDiffuseFlows    10504
# 5            DiffuseFlows    10449
# 6  PowerConsumption_Zone1    27709
# 7  PowerConsumption_Zone2    29621
# 8  PowerConsumption_Zone3    22838

# %% [markdown]
# # Descriptive Statistics

# %%
df.describe()
# Out:
#         Temperature      Humidity     WindSpeed  GeneralDiffuseFlows  \
# count  52416.000000  52416.000000  52416.000000         52416.000000
# mean      18.810024     68.259518      1.959489           182.696614
# std        5.815476     15.551177      2.348862           264.400960
# min        3.247000     11.340000      0.050000             0.004000
# 25%       14.410000     58.310000      0.078000             0.062000
# 50%       18.780000     69.860000      0.086000             5.035500
# 75%       22.890000     81.400000      4.915000           319.600000
# max       40.010000     94.800000      6.483000          1163.000000
#
#        DiffuseFlows  PowerConsumption_Zone1  PowerConsumption_Zone2  \
# count  52416.000000            52416.000000            52416.000000
# mean      75.028022            32344.970564            21042.509082
# std      124.210949             7130.562564             5201.465892
# min        0.011000            13895.696200             8560.081466
# 25%        0.122000            26310.668692            16980.766032
# 50%        4.456000            32265.920340            20823.168405
# 75%      101.000000            37309.018185            24713.717520
# max      936.000000            52204.395120            37408.860760
#
#        PowerConsumption_Zone3
# count            52416.000000
# mean             17835.406218
# std               6622.165099
# min               5935.174070
# 25%              13129.326630
# 50%              16415.117470
# 75%              21624.100420
# max              47598.326360

# %% [markdown]
# # Correlation matrix among all features

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <style type="text/css">
# #T_b67fe_row0_col0, #T_b67fe_row1_col1, #T_b67fe_row2_col2, #T_b67fe_row3_col3, #T_b67fe_row4_col4, #T_b67fe_row5_col5, #T_b67fe_row6_col6, #T_b67fe_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b67fe_row0_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_b67fe_row0_col2 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_b67fe_row0_col3, #T_b67fe_row3_col0 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_b67fe_row0_col4, #T_b67fe_row7_col3 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_b67fe_row0_col5 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_b67fe_row0_col6 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_b67fe_row0_col7 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_b67fe_row1_col0, #T_b67fe_row1_col2, #T_b67fe_row1_col3, #T_b67fe_row1_col4, #T_b67fe_row1_col5, #T_b67fe_row1_col6, #T_b67fe_row1_col7, #T_b67fe_row3_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b67fe_row2_col0 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_b67fe_row2_col1 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_b67fe_row2_col3 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_b67fe_row2_col4 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_b67fe_row2_col5 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_b67fe_row2_col6 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_b67fe_row2_col7 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_b67fe_row3_col2 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_b67fe_row3_col4 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_b67fe_row3_col5 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_b67fe_row3_col6 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_b67fe_row3_col7, #T_b67fe_row6_col4 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_b67fe_row4_col0 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_b67fe_row4_col1 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_b67fe_row4_col2, #T_b67fe_row6_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_b67fe_row4_col3 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_b67fe_row4_col5 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_b67fe_row4_col6 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_b67fe_row4_col7, #T_b67fe_row7_col1 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_b67fe_row5_col0 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_b67fe_row5_col1 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_b67fe_row5_col2, #T_b67fe_row5_col4 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_b67fe_row5_col3 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_b67fe_row5_col6, #T_b67fe_row6_col5 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_b67fe_row5_col7 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_b67fe_row6_col0 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_b67fe_row6_col2 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_b67fe_row6_col3 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_b67fe_row6_col7, #T_b67fe_row7_col0 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_b67fe_row7_col2 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_b67fe_row7_col4 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_b67fe_row7_col5 {
#   background-color: #ec8165;
#   color: #f1f1f1;
# }
# #T_b67fe_row7_col6 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# </style>
# <table id="T_b67fe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b67fe_level0_col0" class="col_heading level0 col0" >Temperature</th>
#       <th id="T_b67fe_level0_col1" class="col_heading level0 col1" >Humidity</th>
#       <th id="T_b67fe_level0_col2" class="col_heading level0 col2" >WindSpeed</th>
#       <th id="T_b67fe_level0_col3" class="col_heading level0 col3" >GeneralDiffuseFlows</th>
#       <th id="T_b67fe_level0_col4" class="col_heading level0 col4" >DiffuseFlows</th>
#       <th id="T_b67fe_level0_col5" class="col_heading level0 col5" >PowerConsumption_Zone1</th>
#       <th id="T_b67fe_level0_col6" class="col_heading level0 col6" >PowerConsumption_Zone2</th>
#       <th id="T_b67fe_level0_col7" class="col_heading level0 col7" >PowerConsumption_Zone3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b67fe_level0_row0" class="row_heading level0 row0" >Temperature</th>
#       <td id="T_b67fe_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_b67fe_row0_col1" class="data row0 col1" >-0.46</td>
#       <td id="T_b67fe_row0_col2" class="data row0 col2" >0.48</td>
#       <td id="T_b67fe_row0_col3" class="data row0 col3" >0.46</td>
#       <td id="T_b67fe_row0_col4" class="data row0 col4" >0.20</td>
#       <td id="T_b67fe_row0_col5" class="data row0 col5" >0.44</td>
#       <td id="T_b67fe_row0_col6" class="data row0 col6" >0.38</td>
#       <td id="T_b67fe_row0_col7" class="data row0 col7" >0.49</td>
#     </tr>
#     <tr>
#       <th id="T_b67fe_level0_row1" class="row_heading level0 row1" >Humidity</th>
#       <td id="T_b67fe_row1_col0" class="data row1 col0" >-0.46</td>
#       <td id="T_b67fe_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_b67fe_row1_col2" class="data row1 col2" >-0.14</td>
#       <td id="T_b67fe_row1_col3" class="data row1 col3" >-0.47</td>
#       <td id="T_b67fe_row1_col4" class="data row1 col4" >-0.26</td>
#       <td id="T_b67fe_row1_col5" class="data row1 col5" >-0.29</td>
#       <td id="T_b67fe_row1_col6" class="data row1 col6" >-0.29</td>
#       <td id="T_b67fe_row1_col7" class="data row1 col7" >-0.23</td>
#     </tr>
#     <tr>
#       <th id="T_b67fe_level0_row2" class="row_heading level0 row2" >WindSpeed</th>
#       <td id="T_b67fe_row2_col0" class="data row2 col0" >0.48</td>
#       <td id="T_b67fe_row2_col1" class="data row2 col1" >-0.14</td>
#       <td id="T_b67fe_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_b67fe_row2_col3" class="data row2 col3" >0.13</td>
#       <td id="T_b67fe_row2_col4" class="data row2 col4" >-0.00</td>
#       <td id="T_b67fe_row2_col5" class="data row2 col5" >0.17</td>
#       <td id="T_b67fe_row2_col6" class="data row2 col6" >0.15</td>
#       <td id="T_b67fe_row2_col7" class="data row2 col7" >0.28</td>
#     </tr>
#     <tr>
#       <th id="T_b67fe_level0_row3" class="row_heading level0 row3" >GeneralDiffuseFlows</th>
#       <td id="T_b67fe_row3_col0" class="data row3 col0" >0.46</td>
#       <td id="T_b67fe_row3_col1" class="data row3 col1" >-0.47</td>
#       <td id="T_b67fe_row3_col2" class="data row3 col2" >0.13</td>
#       <td id="T_b67fe_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_b67fe_row3_col4" class="data row3 col4" >0.56</td>
#       <td id="T_b67fe_row3_col5" class="data row3 col5" >0.19</td>
#       <td id="T_b67fe_row3_col6" class="data row3 col6" >0.16</td>
#       <td id="T_b67fe_row3_col7" class="data row3 col7" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_b67fe_level0_row4" class="row_heading level0 row4" >DiffuseFlows</th>
#       <td id="T_b67fe_row4_col0" class="data row4 col0" >0.20</td>
#       <td id="T_b67fe_row4_col1" class="data row4 col1" >-0.26</td>
#       <td id="T_b67fe_row4_col2" class="data row4 col2" >-0.00</td>
#       <td id="T_b67fe_row4_col3" class="data row4 col3" >0.56</td>
#       <td id="T_b67fe_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_b67fe_row4_col5" class="data row4 col5" >0.08</td>
#       <td id="T_b67fe_row4_col6" class="data row4 col6" >0.04</td>
#       <td id="T_b67fe_row4_col7" class="data row4 col7" >-0.04</td>
#     </tr>
#     <tr>
#       <th id="T_b67fe_level0_row5" class="row_heading level0 row5" >PowerConsumption_Zone1</th>
#       <td id="T_b67fe_row5_col0" class="data row5 col0" >0.44</td>
#       <td id="T_b67fe_row5_col1" class="data row5 col1" >-0.29</td>
#       <td id="T_b67fe_row5_col2" class="data row5 col2" >0.17</td>
#       <td id="T_b67fe_row5_col3" class="data row5 col3" >0.19</td>
#       <td id="T_b67fe_row5_col4" class="data row5 col4" >0.08</td>
#       <td id="T_b67fe_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_b67fe_row5_co

# %% [markdown]
# # Visualization

# %%
df.plot(subplots=True, figsize=(15, 12))
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>], dtype=object)

# %%
# Distribution of PowerConsumption target variable using the average of the 3 zones

df['PowerConsumption_Average'] = df[['PowerConsumption_Zone1', 'PowerConsumption_Zone2','PowerConsumption_Zone3']].mean(axis=1)

plt.figure(figsize=(16,6))
sns.histplot(data=df, x='PowerConsumption_Average', bins=15, kde=True)
plt.show()

# %%
df.plot(y='PowerConsumption_Average',subplots=True, figsize=(15, 5))
# Out:
# array([<AxesSubplot:xlabel='Date'>], dtype=object)

# %% [markdown]
# Average power consumption over one day

# %%
df['1/1/2017 0:00':'1/2/2017 0:00'].plot(y = 'PowerConsumption_Average',subplots=True, figsize=(15, 5))
# Out:
# array([<AxesSubplot:xlabel='Date'>], dtype=object)

# %% [markdown]
# # Hourly data

# %%
df_hourly=dfu.resample('H', on='Date').mean()

# %%
len(df_hourly)
# Out:
# 8736

# %%
df_hourly.plot(subplots=True,figsize=(15,15))
plt.tight_layout()
plt.show()

# %% [markdown]
# # Daily data

# %%
df_daily=dfu.resample('24H', on='Date').mean()

# %%
len(df_daily)
# Out:
# 364

# %%
df_daily.plot(subplots=True,figsize=(15,15))
plt.tight_layout()
plt.show()

# %% [markdown]
# # Monthly data

# %%
df_Month=dfu.resample('M', on='Date').mean()

# %%
len(df_Month)
# Out:
# 12

# %%
df_Month.plot(subplots=True,figsize=(15,15))
plt.tight_layout()
plt.show()
